# %% [markdown]
# *FINAL PIPELINE*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

if project_root not in sys.path:
    sys.path.append(project_root)

from src import config
PROCESSED_DATA_PATH = config.PROCESSED_DATA_PATH
MODEL_DIR = config.MODEL_PATH
BEST_PARAMS_PATH = config.PARAM_PATH
TFIFD_VEC_PATH = config.TFIFD_VEC_PATH
TAGS_VEC_PATH = config.TAGS_VEC_PATH
GENRES_VEC_PATH = config.GENRES_VEC_PATH
TFIFD_MATRIX_PATH = config.TFIFD_MATRIX_PATH
TAGS_MATRIX_PATH = config.TAGS_MATRIX_PATH
GENRES_MATRIX_PATH = config.GENRES_MATRIX_PATH

# %%
try:
    df = pd.read_csv(PROCESSED_DATA_PATH)
except FileNotFoundError:
    print("File not found")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title_romaji', 'format', 'chapters', 'genres',
#        'tags', 'country', 'popularity', 'favourites', 'averageScore', 'status',
#        'description', 'desc_char_len', 'desc_word_count', 'sentiment_score',
#        'tag_count', 'is_Romance', 'is_Comedy', 'is_Drama', 'is_Fantasy',
#        'is_Action', 'is_School Life'],
#       dtype='object')

# %%
df["description"] = df["description"].fillna("")

# %%
cols_to_drop = ['id', 'desc_word_count', 'favourites', 'Unnamed: 0'] 
df_clean = df.drop(columns=cols_to_drop, errors='ignore')

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18250 entries, 0 to 18249
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title_romaji     18250 non-null  object
#  1   format           18250 non-null  object
#  2   chapters         18250 non-null  float64
#  3   genres           18250 non-null  object
#  4   tags             18250 non-null  object
#  5   country          18250 non-null  object
#  6   popularity       18250 non-null  int64
#  7   averageScore     18250 non-null  float64
#  8   status           18250 non-null  object
#  9   description      18250 non-null  object
#  10  desc_char_len    18250 non-null  int64
#  11  sentiment_score  18250 non-null  float64
#  12  tag_count        18250 non-null  int64
#  13  is_Romance       18250 non-null  int64
#  14  is_Comedy        18250 non-null  int64
#  15  is_Drama         18250 non-null  int64
# ...

# %%
df_clean = df_clean.set_index('title_romaji')

# %% [markdown]
# I don't want the model to only reccomend popular titles so I will adjust the "popularity" weight.

# %%
df_engineered = df_clean.copy()
df_engineered['popularity'] = np.log1p(df_engineered['popularity'])

# %%
scaler = MinMaxScaler()
numerical_cols = ['chapters', 'popularity', 'averageScore', 'desc_char_len', 'tag_count']
df_engineered[numerical_cols] = scaler.fit_transform(df_engineered[numerical_cols])

# %%
for col in df_engineered.columns:
    if df_engineered[col].dtype == 'bool':
        df_engineered[col] = df_engineered[col].astype(int)

# %%
df_model = df_engineered.select_dtypes(include=[np.number])

# %%
genre_cols = [c for c in df_model.columns if 'is_' in c]
for col in genre_cols:
    df_model[col] = df_model[col] * 2.0

# %%
quality_cols = ['popularity', 'averageScore']
for col in quality_cols:
    df_model[col] = df_model[col] * 5.0

# %%
pca = PCA(n_components=None)
pca.fit(df_model)
# Out:
# PCA()

# %%
feature_names = df_model.columns
pca_components = pd.DataFrame(pca.components_, columns=feature_names)

# %%
plt.subplot(1, 2, 1)
sns.barplot(x=pca_components.iloc[0].abs(), y=feature_names, color='teal')
plt.title("PC1 (Genre/Topic)")
# Out:
# Text(0.5, 1.0, 'PC1 (Genre/Topic)')

# %%
plt.subplot(1, 2, 2)
sns.barplot(x=pca_components.iloc[1].abs(), y=feature_names, color='orange')
plt.title("PC2 (Quality/Popularity)")
# Out:
# Text(0.5, 1.0, 'PC2 (Quality/Popularity)')

# %%
cosine_sim = cosine_similarity(df_model)

# %%
indices = pd.Series(range(len(df_model)), index=df_model.index)

# %%
def get_recommendations(title, cosine_sim=cosine_sim, top_n=5):
    if title not in indices:
        return f"Error: '{title}' veri setinde bulunamadı."
    
    idx = indices[title]

    sim_scores = list(enumerate(cosine_sim[idx]))

    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    sim_scores = sim_scores[1:top_n+1]
    
    webtoon_indices = [i[0] for i in sim_scores]
    
    return df.iloc[webtoon_indices][['title_romaji', 'popularity', 'averageScore', 'genres']]

# %%
test_webtoon = 'Chainsaw Man'
print(f"Reccomendations for '{test_webtoon}'")
print(get_recommendations(test_webtoon))
# Out:
# Reccomendations for 'Chainsaw Man'
#         title_romaji  popularity  averageScore  \
# 141     Sun-Ken Rock       39805          75.0
# 142  Oemo Jisangjuui       39453          78.0
# 91               GTO       51730          86.0
# 114   Mob Psycho 100       45775          85.0
# 161      The Breaker       37166          80.0
#
#                                                 genres
# 141             ['Action', 'Comedy', 'Drama', 'Ecchi']
# 142      ['Action', 'Comedy', 'Drama', 'Supernatural']
# 91              ['Action', 'Comedy', 'Drama', 'Ecchi']
# 114  ['Action', 'Comedy', 'Drama', 'Psychological',...
# 161                      ['Action', 'Comedy', 'Drama']
